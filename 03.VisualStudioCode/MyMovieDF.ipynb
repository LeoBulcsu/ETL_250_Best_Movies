# %% [markdown]
# # Merge to create my FILMS DataBase

# %% [markdown]
# # Imports

# %%
import pandas as pd
from pymongo import MongoClient
import json

# %%
imdb_csv = pd.read_csv('../02.data_csv/CLEAN/IMDB.CSV', index_col=0)
imdbdf = pd.DataFrame(imdb_csv)

# %%
imdbdf
# Out:
#                         Title  Release Year  Length   Parental  \
# 0    The Shawshank Redemption          1994  2h 22m          R
# 1               The Godfather          1972  2h 55m          R
# 2             The Dark Knight          2008  2h 32m      PG-13
# 3       The Godfather Part II          1974  3h 22m          R
# 4                12 Angry Men          1957  1h 36m   Approved
# ..                        ...           ...     ...        ...
# 245             The 400 Blows          1959  1h 39m  Not Rated
# 246                   Persona          1966  1h 23m  Not Rated
# 247             Life of Brian          1979  1h 34m          R
# 248                   Aladdin          1992  1h 30m          G
# 249        Gangs of Wasseypur          2012  5h 21m  Not Rated
#
#                  Director                                               Cast  \
# 0          Frank Darabont  Tim Robbins , Andy Dufresne , Morgan Freeman ,...
# ...

# %%
metacritic_csv = pd.read_csv('../02.data_csv/CLEAN/METACRITIC.csv', index_col=0)
metacriticdf = pd.DataFrame(metacritic_csv)

# %%
metacriticdf
# Out:
#                     Title                         Genre   Meta Score
# 0     Anatomy of a Murder  Drama,Mystery,Thriller,Crime          9.5
# 1        Bringing Up Baby         Comedy,Romance,Family          9.1
# 2              After Life                 Drama,Fantasy          9.1
# 3                 Gavagai                         Drama          9.1
# 4             The Hustler                   Drama,Sport          9.0
# ...                   ...                           ...          ...
# 9116           Wild Reeds                         Drama          8.0
# 9117        No Home Movie                   Documentary          7.8
# 9118                Solas                         Drama          7.5
# 9119           J.T. Leroy               Biography,Drama          5.5
# 9120           Donnybrook                         Drama          5.3
#
# [9121 rows x 3 columns]

# %%
rotten_csv = pd.read_csv('../02.data_csv/CLEAN/RottenTomatoes.csv', index_col=0)
rottendf = pd.DataFrame(rotten_csv)

# %%
rottendf
# Out:
#                            Title  Tomatometer  Audience_Score
# 0       The Shawshank Redemption          9.1             9.8
# 1                  The Godfather          9.7             9.8
# 2                The Dark Knight          9.4             9.4
# 3          The Godfather Part II          9.6             9.7
# 4                   12 Angry Men          9.7             9.7
# ..                           ...          ...             ...
# 245  Witness for the Prosecution          9.5             9.5
# 246               Paths of Glory          9.6             9.5
# 247                   Inside Out          9.8             8.9
# 248          Hachi: A Dog's Tale          6.4             8.4
# 249           Gangs of Wasseypur          9.4             9.0
#
# [250 rows x 3 columns]

# %%
tmdb_csv = pd.read_csv('../02.data_csv/CLEAN/TMDB.csv', index_col=0)
tmdbdf = pd.DataFrame(tmdb_csv)

# %%
tmdbdf
# Out:
#                            Title                       Org_Title Language  \
# 0       The Shawshank Redemption        The Shawshank Redemption       en
# 1                  The Godfather                   The Godfather       en
# 2                The Dark Knight                 The Dark Knight       en
# 3          The Godfather Part II           The Godfather Part II       en
# 4                   12 Angry Men                    12 Angry Men       en
# ..                           ...                             ...      ...
# 245                The 400 Blows          Les Quatre Cents Coups       fr
# 246                      Persona                         Persona       sv
# 247                Life of Brian                   Life of Brian       en
# 248                      Aladdin                         Aladdin       en
# 249  Gangs of Wasseypur - Part 1  गैंग्स ऑफ़ वास्सेपुर पार्ट - १       hi
#
#      popularity  TMDB Score  vote_count
# ...

# %%
merged_df_1 = pd.merge(imdbdf, tmdbdf, left_index=True, right_index=True)

# %%
merged_df_1 = merged_df_1.drop(columns=['Title_y', 'Org_Title', 'popularity', 'vote_count'])

# %%
merged_df_1 = merged_df_1.rename(columns={'Title_x':'Title'})

# %%
merged_df_2 = pd.merge(merged_df_1, rottendf, on= 'Title')

# %%
merged_df_2
# Out:
#                         Title  Release Year  Length   Parental  \
# 0    The Shawshank Redemption          1994  2h 22m          R
# 1               The Godfather          1972  2h 55m          R
# 2             The Dark Knight          2008  2h 32m      PG-13
# 3       The Godfather Part II          1974  3h 22m          R
# 4                12 Angry Men          1957  1h 36m   Approved
# ..                        ...           ...     ...        ...
# 245             The 400 Blows          1959  1h 39m  Not Rated
# 246                   Persona          1966  1h 23m  Not Rated
# 247             Life of Brian          1979  1h 34m          R
# 248                   Aladdin          1992  1h 30m          G
# 249        Gangs of Wasseypur          2012  5h 21m  Not Rated
#
#                  Director                                               Cast  \
# 0          Frank Darabont  Tim Robbins , Andy Dufresne , Morgan Freeman ,...
# ...

# %%
final_merge = pd.merge(merged_df_2, metacriticdf, on= 'Title', how='left')

# %%
final_merge
# Out:
#                         Title  Release Year  Length   Parental  \
# 0    The Shawshank Redemption          1994  2h 22m          R
# 1               The Godfather          1972  2h 55m          R
# 2             The Dark Knight          2008  2h 32m      PG-13
# 3       The Godfather Part II          1974  3h 22m          R
# 4                12 Angry Men          1957  1h 36m   Approved
# ..                        ...           ...     ...        ...
# 253                   Persona          1966  1h 23m  Not Rated
# 254             Life of Brian          1979  1h 34m          R
# 255                   Aladdin          1992  1h 30m          G
# 256                   Aladdin          1992  1h 30m          G
# 257        Gangs of Wasseypur          2012  5h 21m  Not Rated
#
#                  Director                                               Cast  \
# 0          Frank Darabont  Tim Robbins , Andy Dufresne , Morgan Freeman ,...
# ...

# %%
result = final_merge[final_merge.duplicated('Title', keep=False)]

# %%
result
# Out:
#              Title  Release Year  Length Parental          Director  \
# 33          Psycho          1960  1h 49m        R  Alfred Hitchcock
# 34          Psycho          1960  1h 49m        R  Alfred Hitchcock
# 37   The Lion King          1994  1h 28m        G      Roger Allers
# 38   The Lion King          1994  1h 28m        G      Roger Allers
# 74          Oldboy          2003      2h        R    Park Chan-wook
# 75          Oldboy          2003      2h        R    Park Chan-wook
# 133        The Kid          1921   1h 8m   Passed   Charles Chaplin
# 134        The Kid          1921   1h 8m   Passed   Charles Chaplin
# 154      The Thing          1982  1h 49m        R    John Carpenter
# 155      The Thing          1982  1h 49m        R    John Carpenter
# 170     Inside Out          2015  1h 35m       PG       Pete Docter
# 171     Inside Out          2015  1h 35m       PG       Pete Docter
# 213           Room          2015  1h 58m        R  Lenny Abrahamson
# ...

# %%
rowsToDelete = [33,37,74,133,154,170,213,255]
mergedByTitle = final_merge.drop(final_merge.index[rowsToDelete])

# %%
mergedByTitle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 0 to 257
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           250 non-null    object
#  1   Release Year    250 non-null    int64
#  2   Length          250 non-null    object
#  3   Parental        250 non-null    object
#  4   Director        250 non-null    object
#  5   Cast            250 non-null    object
#  6   Plot            250 non-null    object
#  7   IMDB Rank       250 non-null    int64
#  8   IMDB rating     250 non-null    float64
#  9   Image URL       250 non-null    object
#  10  Language        250 non-null    object
#  11  TMDB Score      250 non-null    float64
#  12  Tomatometer     250 non-null    float64
#  13  Audience_Score  250 non-null    float64
#  14  Genre           188 non-null    object
#  15   Meta Score     188 non-null    float64
# dtypes: float64(5), int64(2), object(9)
# ...

# %%
mergedByTitle = mergedByTitle[['Title','Release Year','Language','Length','Genre','Parental','Director','Cast','Plot','IMDB Rank','IMDB rating','Tomatometer','Audience_Score','TMDB Score',' Meta Score','Image URL']]

# %%
mergedByTitle = mergedByTitle.rename(columns={'Audience_Score':'RT Audience Score', ' Meta Score':'Meta Score'})

# %%
mergedByTitle = mergedByTitle.reset_index()

# %%
mergedByTitle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              250 non-null    int64
#  1   Title              250 non-null    object
#  2   Release Year       250 non-null    int64
#  3   Language           250 non-null    object
#  4   Length             250 non-null    object
#  5   Genre              188 non-null    object
#  6   Parental           250 non-null    object
#  7   Director           250 non-null    object
#  8   Cast               250 non-null    object
#  9   Plot               250 non-null    object
#  10  IMDB Rank          250 non-null    int64
#  11  IMDB rating        250 non-null    float64
#  12  Tomatometer        250 non-null    float64
#  13  RT Audience Score  250 non-null    float64
#  14  TMDB Score         250 non-null    float64
#  15  Meta Score         188 non-null    float64
# ...

# %%
mergedByTitle['Genre'] = mergedByTitle['Genre'].fillna('Unknown')

# %%
mergedByTitle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              250 non-null    int64
#  1   Title              250 non-null    object
#  2   Release Year       250 non-null    int64
#  3   Language           250 non-null    object
#  4   Length             250 non-null    object
#  5   Genre              250 non-null    object
#  6   Parental           250 non-null    object
#  7   Director           250 non-null    object
#  8   Cast               250 non-null    object
#  9   Plot               250 non-null    object
#  10  IMDB Rank          250 non-null    int64
#  11  IMDB rating        250 non-null    float64
#  12  Tomatometer        250 non-null    float64
#  13  RT Audience Score  250 non-null    float64
#  14  TMDB Score         250 non-null    float64
#  15  Meta Score         188 non-null    float64
# ...

# %%
mergedByTitle['Meta Score'] = mergedByTitle['Meta Score'].fillna((mergedByTitle['RT Audience Score']+ mergedByTitle['TMDB Score'])/2)

# %%
mergedByTitle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              250 non-null    int64
#  1   Title              250 non-null    object
#  2   Release Year       250 non-null    int64
#  3   Language           250 non-null    object
#  4   Length             250 non-null    object
#  5   Genre              250 non-null    object
#  6   Parental           250 non-null    object
#  7   Director           250 non-null    object
#  8   Cast               250 non-null    object
#  9   Plot               250 non-null    object
#  10  IMDB Rank          250 non-null    int64
#  11  IMDB rating        250 non-null    float64
#  12  Tomatometer        250 non-null    float64
#  13  RT Audience Score  250 non-null    float64
#  14  TMDB Score         250 non-null    float64
#  15  Meta Score         250 non-null    float64
# ...

# %%
mergedByTitle = mergedByTitle.drop(columns='index')

# %%
mergedByTitle
# Out:
#                         Title  Release Year Language  Length  \
# 0    The Shawshank Redemption          1994       en  2h 22m
# 1               The Godfather          1972       en  2h 55m
# 2             The Dark Knight          2008       en  2h 32m
# 3       The Godfather Part II          1974       en  3h 22m
# 4                12 Angry Men          1957       en  1h 36m
# ..                        ...           ...      ...     ...
# 245             The 400 Blows          1959       fr  1h 39m
# 246                   Persona          1966       sv  1h 23m
# 247             Life of Brian          1979       en  1h 34m
# 248                   Aladdin          1992       en  1h 30m
# 249        Gangs of Wasseypur          2012       hi  5h 21m
#
#                                                  Genre   Parental  \
# 0                                          Drama,Crime          R
# 1                                              Unknown          R
# ...

# %%
mergedByTitle.to_json('../02.1.data_json/BFilms_db.json', orient='index')

# %% [markdown]
# # Upload to MongoDB

# %%
str_conn = 'mongodb://localhost:27017' 

cursor = MongoClient(str_conn)

cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
cursor.list_database_names()
# Out:
# ['admin', 'bulcsufilmsdb', 'companies', 'config', 'local', 'nueva_db']

# %%
db = cursor.bulcsufilmsdb

# %%
colec = db.films

# %%
colec
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'bulcsufilmsdb'), 'films')

# %%
with open('../02.1.data_json/BFilms_db.json') as f:
    
    data_2 = json.load(f)

# %%
data_2
# Out:
# {'0': {'Title': 'The Shawshank Redemption',
#   'Release Year': 1994,
#   'Language': 'en',
#   'Length': '2h 22m',
#   'Genre': 'Drama,Crime',
#   'Parental': 'R',
#   'Director': 'Frank Darabont',
#   'Cast': "Tim Robbins , Andy Dufresne , Morgan Freeman , Ellis Boyd 'Red' Redding , Bob Gunton , Warden Norton , William Sadler , Heywood , Clancy Brown , Captain Hadley , Gil Bellows , Tommy , Mark Rolston , Bogs Diamond , James Whitmore , Brooks Hatlen , Jeffrey DeMunn , 1946 D.A. , Larry Brandenburg , Skeet , Neil Giuntoli , Jigger , Brian Libby , Floyd , David Proval , Snooze , Joseph Ragno , Ernie , Jude Ciccolella , Guard Mert , Paul McCrane , Guard Trout , Renee Blaine , Andy Dufresne's Wife , Scott Mann , Glenn Quentin",
#   'Plot': 'Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.',
#   'IMDB Rank': 1,
#   'IMDB rating': 9.3,
#   'Tomatometer': 9.1,
#   'RT Audience Score': 9.8,
# ...

# %%
for key, value in data_2.items():
    colec.insert_one(value)

# %%
BFilms = pd.read_json('../02.1.data_json/BFilms_db.json')

# %%
BFilmsdf = pd.DataFrame(BFilms)

# %%
BFilmsdf = BFilmsdf.T

# %%
BFilmsdf_scores = BFilmsdf[['Title', 'IMDB rating','Tomatometer','RT Audience Score','TMDB Score','Meta Score']]

# %%
BFilmsdf_scores['BFilms Score'] = BFilmsdf[['IMDB rating','Tomatometer','RT Audience Score','TMDB Score','Meta Score']].mean(axis = 1)
# Out:
# /var/folders/0d/cvfvbfy91kx0r6vqkfyf353r0000gn/T/ipykernel_41431/1967434527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BFilmsdf_scores['BFilms Score'] = BFilmsdf[['IMDB rating','Tomatometer','RT Audience Score','TMDB Score','Meta Score']].mean(axis = 1)

# %%
BFilmsdf_scores
# Out:
#                         Title IMDB rating Tomatometer RT Audience Score  \
# 0    The Shawshank Redemption         9.3         9.1               9.8
# 1               The Godfather         9.2         9.7               9.8
# 2             The Dark Knight         9.0         9.4               9.4
# 3       The Godfather Part II         9.0         9.6               9.7
# 4                12 Angry Men         9.0         9.7               9.7
# ..                        ...         ...         ...               ...
# 245             The 400 Blows         8.1         9.4               9.4
# 246                   Persona         8.1         9.4               9.4
# 247             Life of Brian         8.0         9.6               9.3
# 248                   Aladdin         8.0         9.5               9.2
# 249        Gangs of Wasseypur         8.2         9.4               9.0
#
#     TMDB Score Meta Score BFilms Score
# 0          8.7        8.0         8.98
# ...

# %%
BFilmsdf_scores_sorted = BFilmsdf_scores.sort_values(by='BFilms Score', ascending=False)

# %% [markdown]
# # INSIGHTS

# %%
BFilmsdf_scores_sorted.reset_index(drop=True).head(30)
# Out:
#                                                 Title IMDB rating Tomatometer  \
# 0                                       The Godfather         9.2         9.7
# 1                                        12 Angry Men         9.0         9.7
# 2                                    Schindler's List         9.0         9.8
# 3                                         Rear Window         8.5         9.8
# 4                                          Casablanca         8.5         9.9
# 5                               The Godfather Part II         9.0         9.6
# 6                                 Singin' in the Rain         8.3        10.0
# 7                                       Spirited Away         8.6         9.6
# 8                      The Good, the Bad and the Ugly         8.8         9.7
# 9                                         City Lights         8.5         9.5
# 10                                             Psycho         8.5         9.7
# ...
